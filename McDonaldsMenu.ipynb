# %% [markdown]
# <a href="https://colab.research.google.com/github/setyo-dwi-pratama/FGA-DTS-KOMINFO-Challenge/blob/main/McDonaldsMenu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Nutrition Facts for McDonald's Menu**
#
# **Deskripsi**
#
# Dataset diperoleh dari website McDonald's
#
# Ray Kroc ingin membangun sistem restoran yang terkenal untuk penyediaan makanan dengan kualitas tinggi dan metode penyiapan yang seragam secara konsisten. Dia ingin menyajikan burger, roti, kentang goreng, dan minuman yang rasanya sama di Alaska seperti di Alabama. Untuk mencapai tujuannya, dia memilih jalan yang unik: mengajak pemegang waralaba dan pemasok untuk membeli visinya, bekerja bukan untuk McDonald's tetapi untuk diri mereka sendiri, bersama dengan McDonald's. Banyak item menu paling terkenal di McDonald - seperti Big Mac, Filet-O-Fish, dan Egg McMuffin.
#
# **Content**
#
# Kumpulan data ini memberikan analisis nutrisi untuk setiap item menu di menu McDonald's AS, diantaranya breakfast, beef burgers, chicken and fish sandwiches, fries, salads, soda, coffee and tea, milkshakes, dan desserts.

# %% [markdown]
# # **Packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Dataset**

# %%
df = pd.read_csv("https://raw.githubusercontent.com/setyo-dwi-pratama/FGA-DTS-KOMINFO-Challenge/main/menu.csv")
df.head()
# Out:
#     Category  ... Iron (% Daily Value)
# 0  Breakfast  ...                   15
# 1  Breakfast  ...                    8
# 2  Breakfast  ...                   10
# 3  Breakfast  ...                   15
# 4  Breakfast  ...                   10
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(' ','_')

# %%
df.columns
# Out:
# Index(['Category', 'Item', 'Serving_Size', 'Calories', 'Calories_from_Fat',
#        'Total_Fat', 'Total_Fat_(%_Daily_Value)', 'Saturated_Fat',
#        'Saturated_Fat_(%_Daily_Value)', 'Trans_Fat', 'Cholesterol',
#        'Cholesterol_(%_Daily_Value)', 'Sodium', 'Sodium_(%_Daily_Value)',
#        'Carbohydrates', 'Carbohydrates_(%_Daily_Value)', 'Dietary_Fiber',
#        'Dietary_Fiber_(%_Daily_Value)', 'Sugars', 'Protein',
#        'Vitamin_A_(%_Daily_Value)', 'Vitamin_C_(%_Daily_Value)',
#        'Calcium_(%_Daily_Value)', 'Iron_(%_Daily_Value)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving_Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories_from_Fat              260 non-null    int64
#  5   Total_Fat                      260 non-null    float64
#  6   Total_Fat_(%_Daily_Value)      260 non-null    int64
#  7   Saturated_Fat                  260 non-null    float64
#  8   Saturated_Fat_(%_Daily_Value)  260 non-null    int64
#  9   Trans_Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol_(%_Daily_Value)    260 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# Category                         0
# Item                             0
# Serving_Size                     0
# Calories                         0
# Calories_from_Fat                0
# Total_Fat                        0
# Total_Fat_(%_Daily_Value)        0
# Saturated_Fat                    0
# Saturated_Fat_(%_Daily_Value)    0
# Trans_Fat                        0
# Cholesterol                      0
# Cholesterol_(%_Daily_Value)      0
# Sodium                           0
# Sodium_(%_Daily_Value)           0
# Carbohydrates                    0
# Carbohydrates_(%_Daily_Value)    0
# Dietary_Fiber                    0
# Dietary_Fiber_(%_Daily_Value)    0
# Sugars                           0
# Protein                          0
# Vitamin_A_(%_Daily_Value)        0
# Vitamin_C_(%_Daily_Value)        0
# Calcium_(%_Daily_Value)          0
# Iron_(%_Daily_Value)             0
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
df['Category'].value_counts()
# Out:
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Beverages             27
# Chicken & Fish        27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: Category, dtype: int64

# %%
df['Category'].value_counts().plot.pie(autopct='%.0f%%')

# %% [markdown]
# # **Visualisasi**

# %%
#Membuat Fungsi untuk melihat kandungan pada Dataset
def data(var1, var2, col):
  df.pivot_table(var1, var2).plot(kind='bar',stacked=True,color=col)

# %%
data("Calories","Category","r")

# %%
data("Cholesterol","Category","r")

# %%
data("Sodium","Category","r")

# %%
data("Carbohydrates","Category","r")

# %%
data("Dietary_Fiber","Category","r")

# %%
data("Sugars","Category","r")

# %%
data("Protein","Category","r")

# %%
data("Vitamin_A_(%_Daily_Value)","Category","r")

# %%
df.columns
# Out:
# Index(['Category', 'Item', 'Serving_Size', 'Calories', 'Calories_from_Fat',
#        'Total_Fat', 'Total_Fat_(%_Daily_Value)', 'Saturated_Fat',
#        'Saturated_Fat_(%_Daily_Value)', 'Trans_Fat', 'Cholesterol',
#        'Cholesterol_(%_Daily_Value)', 'Sodium', 'Sodium_(%_Daily_Value)',
#        'Carbohydrates', 'Carbohydrates_(%_Daily_Value)', 'Dietary_Fiber',
#        'Dietary_Fiber_(%_Daily_Value)', 'Sugars', 'Protein',
#        'Vitamin_A_(%_Daily_Value)', 'Vitamin_C_(%_Daily_Value)',
#        'Calcium_(%_Daily_Value)', 'Iron_(%_Daily_Value)'],
#       dtype='object')

# %%
data("Vitamin_C_(%_Daily_Value)","Category","r")

# %%
data("Calcium_(%_Daily_Value)","Category","r")

# %%
data("Iron_(%_Daily_Value)","Category","r")

# %% [markdown]
# # Berapa banyak kalori rata-rata yang terkandung pada makanan di McDonalds?

# %%
df['Category'].value_counts()
# Out:
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Beverages             27
# Chicken & Fish        27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: Category, dtype: int64

# %%
Avg_Calori = df.loc[(df['Category'] == 'Breakfast') | (df['Category'] == 'Chicken & Fish') | (df['Category'] == 'Beef & Pork') | (df['Category'] == 'Snacks & Sides') | (df['Category'] == 'Salads')]

# %%
Avg_Calori['Category'].value_counts()
# Out:
# Breakfast         42
# Chicken & Fish    27
# Beef & Pork       15
# Snacks & Sides    13
# Salads             6
# Name: Category, dtype: int64

# %%
Avg_Calori
# Out:
#            Category  ... Iron_(%_Daily_Value)
# 0         Breakfast  ...                   15
# 1         Breakfast  ...                    8
# 2         Breakfast  ...                   10
# 3         Breakfast  ...                   15
# 4         Breakfast  ...                   10
# ..              ...  ...                  ...
# 98   Snacks & Sides  ...                    8
# 99   Snacks & Sides  ...                    2
# 100  Snacks & Sides  ...                    4
# 101  Snacks & Sides  ...                    0
# 102  Snacks & Sides  ...                    4
#
# [103 rows x 24 columns]

# %%
Avg_Calori['Calories'].mean()
# Out:
# 478.3980582524272

# %% [markdown]
# # Seberapa banyak minuman (Soda atau Kopi) yang berkontribusi pada asupan kalori keseluruhan?

# %%
Count_drink= df[['Category','Calories']].groupby('Category').sum()

# %%
Count_drink
# Out:
#                     Calories
# Category
# Beef & Pork             7410
# Beverages               3070
# Breakfast              22120
# Chicken & Fish         14930
# Coffee & Tea           26970
# Desserts                1555
# Salads                  1620
# Smoothies & Shakes     14880
# Snacks & Sides          3195

# %%
Count_drink['Calories'].plot(.pie(autopct='%.0f%%'))

# %% [markdown]
# # Does ordered grilled chicken instead of crispy increase a sandwich's nutritional value?

# %%
grilled = df[df['Item'].str.contains('Grilled')].reset_index(drop=True)
grilled_sandwich = grilled[grilled['Item'].str.contains('Sandwich')].reset_index(drop=True)
crispy = df[df['Item'].str.contains('Crispy')].reset_index(drop=True)
crispy_sandwich = crispy[crispy['Item'].str.contains('Sandwich')].reset_index(drop=True)

# %%
grilled.pivot_table('Calories','Item').plot(kind='bar',stacked=True,color='r')

# %%
grilled_sandwich.pivot_table('Calories','Item').plot(kind='bar',stacked=True,color='r')

# %%
#crispy

# %%
#crispy_sandwich

# %% [markdown]
# # Item yang mengandung putih telur dengan telur utuh?

# %%
egg_whites = df[df['Item'].str.contains('Whites')].reset_index(drop=True)
egg = df[df['Item'].str.contains('Egg') & ~df['Item'].str.contains('Whites')].reset_index(drop=True)

# %%
egg_whites['Item']
# Out:
# 0                      Sausage McMuffin with Egg Whites
# 1     Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 2     Bacon, Egg & Cheese Biscuit with Egg Whites (L...
# 3     Sausage Biscuit with Egg Whites (Regular Biscuit)
# 4       Sausage Biscuit with Egg Whites (Large Biscuit)
# 5        Bacon, Egg & Cheese McGriddles with Egg Whites
# 6      Sausage, Egg & Cheese McGriddles with Egg Whites
# 7             Bacon, Egg & Cheese Bagel with Egg Whites
# 8       Big Breakfast with Egg Whites (Regular Biscuit)
# 9         Big Breakfast with Egg Whites (Large Biscuit)
# 10    Big Breakfast with Hotcakes and Egg Whites (Re...
# 11    Big Breakfast with Hotcakes and Egg Whites (La...
# Name: Item, dtype: object

# %%
egg['Item']
# Out:
# 0                                      Egg McMuffin
# 1                                 Egg White Delight
# 2                         Sausage McMuffin with Egg
# 3                              Steak & Egg McMuffin
# 4     Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# 5       Bacon, Egg & Cheese Biscuit (Large Biscuit)
# 6        Sausage Biscuit with Egg (Regular Biscuit)
# 7          Sausage Biscuit with Egg (Large Biscuit)
# 8             Steak & Egg Biscuit (Regular Biscuit)
# 9                    Bacon, Egg & Cheese McGriddles
# 10                 Sausage, Egg & Cheese McGriddles
# 11                        Bacon, Egg & Cheese Bagel
# 12                        Steak, Egg & Cheese Bagel
# Name: Item, dtype: object

# %% [markdown]
# # Berapa jumlah makanan paling sedikit yang dapat Anda pesan yang ada pada menu untuk memenuhi kebutuhan gizi perhari?
